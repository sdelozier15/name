# %%
import pandas as pd
import seaborn as sns
from pandas.plotting import scatter_matrix
from matplotlib import pyplot

# %%
data = pd.read_csv("FINAL_ML.csv")
df = pd.DataFrame(data)
df2 = df.drop(columns = "Unnamed: 0")
df2.columns
# Out:
# Index(['pedmort_2016', 'pedmort_53mean', 'pedmort_3mean', 'Code', 'sanit_2015',
#        'sanit_21mean', 'sanit_3mean', 'Country or region', 'Outcome',
#        'democ_2018', 'latitude', 'within_tropics'],
#       dtype='object')

# %%
ml = df2[['Outcome', 'pedmort_2016', 'pedmort_53mean', 'pedmort_3mean', 'Code', 'sanit_2015',
       'sanit_21mean', 'sanit_3mean',
       'democ_2018', 'latitude', 'within_tropics']]
ml
# Out:
#      Outcome  pedmort_2016  pedmort_53mean  pedmort_3mean Code  sanit_2015  \
# 0          0          6.79       20.641667       7.316667  AFG        31.9
# 1          0          0.88        3.666389       0.940000  ALB        93.2
# 2          1          1.04        3.361333       1.143333  ARG        96.4
# 3          0          1.26        4.465526       1.400000  ARM        89.5
# 4          1          0.35        1.239444       0.383333  AUS       100.0
# ..       ...           ...             ...            ...  ...         ...
# 120        1          2.25        6.740000       2.566667  UZB       100.0
# 121        0          3.09        3.974630       2.286667  VEN        94.4
# 122        0          2.09        5.282600       2.160000  VNM        78.0
# 123        0          6.00       15.892778       6.510000  ZMB        43.9
# 124        0          5.03       10.213519       5.713333  ZWE        36.8
#
# ...

# %%
sns.heatmap(ml.corr(), annot=True, fmt=".2f")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-4661418b787b> in <module>
#       1 sns.heatmap(ml.corr(), annot=True, fmt=".2f")
# ----> 2 plt.show()
#
# NameError: name 'plt' is not defined

# %%
ax = sns.boxplot(data=ml, orient="h", palette="Set2")

# %%
# histograms
ml.hist()
pyplot.show()

# %%
# scatter plot matrix
scatter_matrix(ml)
pyplot.show()
