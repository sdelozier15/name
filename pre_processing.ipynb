# %%
import pandas as pd

# %%
path = "life-expectancy.csv"
le_db = pd.read_csv(path)
le_df = pd.DataFrame(data=le_db)

path2 = "child_labor.csv"
labor_db = pd.read_csv(path2)
labor_df = pd.DataFrame(data=labor_db)

# path3 = "annual-number-of-deaths-by-cause.csv"
# ann_death_db = pd.read_csv(path3)
# ann_death_df = pd.DataFrame(ann_death_db)

# path4 = "number-of-deaths-by-risk-factor.csv"
# no_death_db = pd.read_csv(path4)
# no_death_df = pd.DataFrame(no_death_db)

path5 = "homicide-rate.csv"
homo_db = pd.read_csv(path5)
homo_df = pd.DataFrame(homo_db)

path6 = "share-deaths-from-natural-disasters.csv"
nat_db = pd.read_csv(path6)
nat_df = pd.DataFrame(nat_db)

path7 = "prevalence-of-undernourishment.csv"
nour_db = pd.read_csv(path7)
nour_df = pd.DataFrame(nour_db)

path10 = "share-of-population-with-improved-sanitation-faciltities.csv"
toilet_db = pd.read_csv(path10)
toilet_df = pd.DataFrame(toilet_db)
#Improved sanitation facilities (% of population with access) (% of population with access)

path11 = "child-mortality-igme.csv"
childX_db = pd.read_csv(path11)
childX_df = pd.DataFrame(childX_db)

path13 = "CINC_sim20.csv"
CINC_db = pd.read_csv(path13)
CINC_df = pd.DataFrame(CINC_db)

path = "democ.csv"
d_db = pd.read_csv(path)
democ_df = pd.DataFrame(data=d_db)


path20 = "gdp-per-capita-worldbank.csv"
gdp_db = pd.read_csv(path20)
gdp_df = pd.DataFrame(data=gdp_db)

path21 = "population-density.csv"
pop_db = pd.read_csv(path21)
pop_df = pd.DataFrame(data=pop_db)

path25 = "gdp_2017.csv"
gdp_db2 = pd.read_csv(path25)
gdp_done = pd.DataFrame(data=gdp_db2)

path12 = "scores_4ML.csv"
scores_4ML = pd.read_csv(path12)
scores_4df = pd.DataFrame(scores_4ML)

# %%
pop_df.columns
# Out:
# Index(['Entity', 'Code', 'Year', 'pop_dens'], dtype='object')

# %%
gdp9 = gdp_done.drop(columns = 'Year')
gdp9.head()
# Out:
#   Code      gdp_2017    gdp_mean3     gdp_mean5
# 0  AFG   1803.987487   1805.23318   1823.772232
# 1  ALB  11803.430590  11376.74139  10948.995770
# 2  DZA  13913.839360  13853.24774  13576.443040
# 3  AGO   5819.494971  6006.537058   6077.444985
# 4  ATG  21490.942660  20886.30259  20017.282770

# %%
ML_w_gdp = scores_df7.merge(gdp9, on='Code', how = 'inner')
#len(ML_w_gdp)
#ML_w_gdp.head()
#len(scores_df7)
ML_w_gdp.to_csv("ML2_131.csv", index=True)

# %%
len(gdp_df)
# Out:
# 6407

# %%
scores_df = scores_4df.drop(columns=['Unnamed: 0', 'Unnamed: 0.1'])
scores_df.head()
#scores_4df.columns
# Out:
#    pedmort_2016  pedmort_53mean  pedmort_3mean Code  sanit_2015  sanit_21mean  \
# 0          6.79       20.641667       7.316667  AFG        31.9     24.266667
# 1          0.88        3.666389       0.940000  ALB        93.2     84.009091
# 2          1.04        3.361333       1.143333  ARG        96.4     91.477273
# 3          1.26        4.465526       1.400000  ARM        89.5     89.435000
# 4          0.35        1.239444       0.383333  AUS       100.0    100.000000
#
#    sanit_3mean  maln_12mean  maln_3mean  maln_2016  nat_dis2017  \
# 0    31.133333    32.115385   27.466667       30.3     0.068639
# 1    92.666667     8.761538    5.566667        5.5     0.004623
# 2    95.800000     4.315385    3.500000        3.8     0.000301
# 3    89.500000    10.792308    4.400000        4.3     0.000000
# 4   100.000000     2.500000    2.500000        2.5     0.007034
#
#    nat_dis_23mean  nat_dis_3mean  homoc_2017  homoc_3mean  homoc_23mean  \
# ...

# %%
gdp_df.columns
# Out:
# Index(['Entity', 'Code', 'Year',
#        'GDP per capita (int.-$) (constant 2011 international $)'],
#       dtype='object')

# %%
#democ
pop_df2 = pop_df.dropna()
len(pop_df2)
# Out:
# 11978

# %%
cinc = CINC_df.dropna()
#len(toilet)
cincs = cinc.rename(columns = {'stateabb': 'Code'})
cincs.columns
#len(cinc_17y) == 134 (result = 54)
#len(cincs) == 191
# Out:
# Index(['Code', '2009', '2010', '2011', '2012', '2013', '2014', '2015', '2016',
#        '2017', '2018', '2019'],
#       dtype='object')

# %%
pop_dens = pop_df2.pivot(index='Code', columns='Year', values='pop_dens')
# len(glob_pedX)
# democs.columns = democs.columns.astype(str)
# democs.columns
#len(democs) === 172
#democ1 = democs.dropna()
#len(democ1) == 17

#gdp.to_csv("gdp_196_countries.csv", index=True)
#len(pop_dens)

pop2 = pop_dens.dropna()
len(pop2)
pop2.to_csv("pop_205_countries.csv", index=True)

# %%
#gdp2 = gdp1.columns.astype(str)
gdp1['2017']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2896             try:
# -> 2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index_class_helper.pxi in pandas._libs.index.Int64Engine._check_type()
#
# KeyError: '2017'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-253-4fd413337a75> in <module>
#       1 #gdp2 = gdp1.columns.astype(str)
# ----> 2 gdp1['2017']
#
# /usr/local/lib/python3.7/site-packages/pandas/core/frame.py in __getitem__(self, key)
# ...

# %%
gdp_2017 = gdp2[['Code','2017']]
len(gdp_2017)

# w_gdp_df = scores_df7.merge(gdp1, on='Code', how = 'inner').rename(columns = {'2019':'cinc_2019'})
# len(w_gdp_df)
# Out:
# /usr/local/lib/python3.7/site-packages/pandas/core/indexes/base.py:4291: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   result = getitem(key)
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-250-7cdeafb4ab72> in <module>
# ----> 1 gdp_2017 = gdp2[['Code','2017']]
#       2 len(gdp_2017)
#       3
#       4 # w_gdp_df = scores_df7.merge(gdp1, on='Code', how = 'inner').rename(columns = {'2019':'cinc_2019'})
#       5 # len(w_gdp_df)
#
# /usr/local/lib/python3.7/site-packages/pandas/core/indexes/base.py in __getitem__(self, key)
#    4289
#    4290         key = com.values_from_object(key)
# -> 4291         result = getitem(key)
# ...

# %%
code = pop2['Code']
col3 = pop2.loc[: , '1961':'2017']
#col_ranges = col3.max(axis=1) - col3.min(axis=1)
#cinc_3mean = col_ranges / 2
gdp_roc27 = col3.mean()
roc_df1 = pd.concat([cinc_3mean2, code], axis = 1)
roc_df = roc_df1.rename(columns={0:'cinc_3mean2'})
len(roc_df)
# Out:
# 187

# %%
CINC_dfs['2019']
# Out:
# 1      0.001715
# 2      0.000155
# 3      0.004050
# 4     -0.000003
# 5      0.002648
#          ...
# 209    0.000005
# 211    0.001930
# 213    0.000165
# 214    0.000841
# 216    0.000777
# Name: 2019, Length: 183, dtype: float64

# %%
scores_df_cinc20['cinc_3mean2'] = roc_df['cinc_3mean2']
#scores_df_cinc20.head()
#scores_df_cinc20.isna().sum()
# Out:
# pedmort_2016           0
# pedmort_53mean         0
# pedmort_3mean          0
# Code                   0
# sanit_2015             0
# sanit_21mean           0
# sanit_3mean            0
# maln_12mean            0
# maln_3mean             0
# maln_2016              0
# nat_dis2017            0
# nat_dis_23mean         0
# nat_dis_3mean          0
# homoc_2017             0
# homoc_3mean            0
# homoc_23mean           0
# Country or region      0
# Outcome                0
# sanit_25roc            0
# homoc_27roc            0
# maln_16roc             0
# nat_dis_17roc          0
# cinc_20roc             0
# cinc_2019             18
# cinc_3mean            18
# cinc_3mean2          127
# dtype: int64

# %%
#scores_df_cinc23['cinc_3mean'] = CINC_dfs['2019']
scores_df_cinc23.isna().sum()
# Out:
# pedmort_2016          0
# pedmort_53mean        0
# pedmort_3mean         0
# Code                  0
# sanit_2015            0
# sanit_21mean          0
# sanit_3mean           0
# maln_12mean           0
# maln_3mean            0
# maln_2016             0
# nat_dis2017           0
# nat_dis_23mean        0
# nat_dis_3mean         0
# homoc_2017            0
# homoc_3mean           0
# homoc_23mean          0
# Country or region     0
# Outcome               0
# sanit_25roc           0
# homoc_27roc           0
# maln_16roc            0
# nat_dis_17roc         0
# cinc_20roc            0
# cinc_2019            18
# dtype: int64

# %%
CINC_dfs.columns
# Out:
# Index(['Code', '1999', '2000', '2001', '2002', '2003', '2004', '2005', '2006',
#        '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015',
#        '2016', '2017', '2018', '2019'],
#       dtype='object')

# %%
cinc_2019 = CINC_dfs[['Code','2019']]
len(cinc_2019)
# Out:
# 183

# %%
CINC_dfs.head()
# Out:
#   Code      1999      2000      2001      2002      2003      2004      2005  \
# 1  AFG  0.004087  0.004098  0.001215  0.001580  0.001706  0.001575  0.001211
# 2  ALB  0.000304  0.000570  0.000386  0.000399  0.000355  0.000356  0.000361
# 3  DZA  0.004327  0.004255  0.004325  0.003857  0.003689  0.003658  0.003850
# 4  AND  0.000003  0.000003  0.000002  0.000003  0.000003  0.000003  0.000003
# 5  AGO  0.001650  0.001913  0.002032  0.001877  0.001997  0.001959  0.002012
#
#        2006      2007  ...      2010      2011      2012      2013      2014  \
# 1  0.001230  0.001446  ...  0.001836  0.002407  0.002734  0.001775  0.001765
# 2  0.000364  0.000282  ...  0.000296  0.000311  0.000309  0.000246  0.000231
# 3  0.003782  0.003919  ...  0.003946  0.004258  0.004188  0.004014  0.004020
# 4  0.000003  0.000003  ...  0.000003  0.000002  0.000002 -0.000001 -0.000002
# 5  0.002097  0.002189  ...  0.002309  0.002318  0.002416  0.002402  0.002443
#
# ...

# %%
scores_df_cinc21 = scores_df7.merge(cinc_2019, on='Code', how = 'inner').rename(columns = {'2019':'cinc_2019'})
#scores_df4 = scores_df3.drop(columns=['sanit_25roc_y']).rename(columns={'sanit_25roc_x':'sanit_25roc'})
#len(scores_df_cinc20)
len(scores_df_cinc21) ##cinc_2019
#len(scores_df7) == 132 / 196
#len(scores_df8) == 54
#len(scores_df9) == 61
# len(scores_df_cinc) ==111
# len(scores_df_cinc20) == 127
# len(scores_df_cinc15) == 127
# len(scores_df_cinc10) == 127
# Out:
# 127

# %%
len(scores_df_cinc20)  ##cinc_20roc
# Out:
# 127

# %%
len(no_death_df)
# Out:
# 6468

# %%
no_death_df.columns
# Out:
# Index(['Entity', 'Code', 'Year', 'Unsafe water source (deaths)',
#        'Poor sanitation (deaths)',
#        'No access to handwashing facility (deaths)',
#        'Indoor air pollution (deaths)', 'Non-exclusive breastfeeding (deaths)',
#        'Discontinued breastfeeding (deaths)', 'Child wasting (deaths)',
#        'Child stunting (deaths)', 'Low birth weight (deaths)',
#        'Secondhand smoke (deaths)', 'Alcohol use (deaths)',
#        'Drug use (deaths)', 'Diet low in fruits (deaths)',
#        'Diet low in vegetables (deaths)', 'Unsafe sex (deaths)',
#        'Low physical activity (deaths)', 'High blood sugar (deaths)',
#        'High cholesterol (deaths)', 'Obesity (deaths)',
#        'High blood pressure (deaths)', 'Smoking (deaths)',
#        'Iron deficiency (deaths)', 'Zinc deficiency (deaths)',
#        'Vitamin-A deficiency (deaths)', 'Low bone mineral density (deaths)',
#        'Air pollution (outdoor & indoor) (deaths)',
# ...

# %%
ann_death_df['Execution'].isna().sum()
# Out:
# 6419

# %%
no_null_con = ann_death_df[['Code', 'Year','Conflict (deaths)']].dropna().copy()
len(no_null_con)
# Out:
# 5488

# %%
no_null_water = no_death_df[['Code', 'Year','Unsafe water source (deaths)',
       'Poor sanitation (deaths)',
       'No access to handwashing facility (deaths)',]].dropna().copy()
#no_null_conflict = ann_death_df['Conflict (deaths)'].dropna()
#len(no_null_conflict)
len(no_null_water)
# Out:
# 5488

# %%
no_null_conflict = no_null_con.pivot(index='Code', columns='Year', values='Conflict (deaths)')
no_null_conflict
# Out:
# Year         1990         1991         1992          1993         1994  \
# Code
# AFG   1489.999290  3370.000153  4343.997795   4097.000207  8959.000461
# AGO   2755.999916   595.000098  2424.999911  12398.034990  4116.997104
# ALB      0.000000     0.000000     1.000000      2.000000    18.000000
# AND      0.000000     0.000000     0.000000      0.000000     0.000000
# ARE      0.000000     6.000000     0.000000      0.000000     0.000000
# ...           ...          ...          ...           ...          ...
# WSM      0.000000     0.000000     0.000000      0.000000     0.000000
# YEM      0.000000     1.000000    24.000000      0.000000  1502.999194
# ZAF    371.999995   462.000020   801.999905    239.000000   509.999979
# ZMB     50.000002     0.000000     0.000000      1.000000     0.000000
# ZWE     23.000000     0.000000     0.000000      0.000000     0.000000
#
# Year         1995         1996         1997         1998         1999  ...  \
# ...

# %%
sanit = no_null_water.pivot(index='Code', columns='Year', values=['Unsafe water source (deaths)',
       'Poor sanitation (deaths)',
       'No access to handwashing facility (deaths)'])
#len(sanit)
sanit
#'Execution', 'Terrorism (deaths)', 'Natural disasters (deaths)', 'Poisonings (deaths)'
# Out:
#      Unsafe water source (deaths)                                            \
# Year                         1990          1991          1992          1993
# Code
# AFG                   7554.049543   7359.676749   7650.437822  10270.731380
# AGO                  21806.299020  22364.783210  22654.263300  23151.768520
# ALB                     50.125767     51.042750     48.824502     43.786246
# AND                      0.008650      0.009347      0.009843      0.010465
# ARE                     15.849045     14.814519     14.010962     13.433693
# ...                           ...           ...           ...           ...
# WSM                      4.425890      4.236741      4.093085      3.967444
# YEM                  18845.833070  18588.256340  18345.803570  18140.913790
# ZAF                  18730.253630  18300.651490  17951.708270  17424.897910
# ZMB                   9854.601488  10663.746570  10702.819500  10559.413070
# ...

# %%
df = labor_df.pivot(index='ref_area', columns='time', values='obs_value')

# %%
#drop rows with >5 columns NaN
# import numpy as np
# d = np.where(df.isnull().sum(axis=1)>5)
# df= df.drop(df.index[d])
# len(df)
# Out:
# 42

# %%
homo_df2 = homo_df.dropna()
len(homo_df2)
# Out:
# 5488

# %%
homo_death = homo_df2.pivot(index='Code', columns='Year', values='Homo_per_100k')
homo_death.head()
# Out:
# Year       1990       1991       1992       1993       1994       1995  \
# Code
# AFG   12.791298  14.666324  13.721925  13.326211  14.824391  14.768702
# AGO    5.584680   5.588083   5.631152   5.764013   5.834371   5.652938
# ALB    4.861277   5.790362   6.382363   6.958544   7.444144   8.589941
# AND    1.212121   1.211867   1.205398   1.166228   1.131385   1.094113
# ARE    1.431810   1.365581   1.316104   1.279358   1.253182   1.239089
#
# Year       1996       1997       1998       1999  ...       2008       2009  \
# Code                                              ...
# AFG   15.895722  13.913738  14.495322  13.813267  ...  12.485842  12.111042
# AGO    5.206046   5.034535   5.532469   5.230486  ...   4.148367   4.018229
# ALB    9.858193  11.429091  11.760979  10.606425  ...   2.614556   2.333373
# AND    1.062288   1.027576   0.996053   0.965017  ...   0.818800   0.803255
# ARE    1.218248   1.205322   1.228324   1.244466  ...   1.259768   1.288892
#
# ...

# %%
col3 = le_df.loc[: , "1950":"2019"]
col_ranges = col3.max(axis=1) - col3.min(axis=1)
le_69roc = col_ranges / 69
roc_df1 = pd.concat([le_69roc, code], axis = 1)
roc_df = roc_df1.rename(columns={0:'le_69roc'})
roc_df

# %%
nour = nour_df.dropna()
len(nour)
# Out:
# 2798

# %%
glob_nour = nour.pivot(index='Code', columns='Year', values='Prevalence of undernourishment (% of population) (% of population)')
len(glob_nour)
# Out:
# 166

# %%
col3 = le_df.loc[: , "1950":"2019"]
col_ranges = col3.max(axis=1) - col3.min(axis=1)
le_69roc = col_ranges / 69
roc_df1 = pd.concat([le_69roc, code], axis = 1)
roc_df = roc_df1.rename(columns={0:'le_69roc'})
roc_df

# %%
toil = toilet_df.dropna()
len(toil)
# Out:
# 5050

# %%
col3 = le_df.loc[: , "1950":"2019"]
col_ranges = col3.max(axis=1) - col3.min(axis=1)
le_69roc = col_ranges / 69
roc_df1 = pd.concat([le_69roc, code], axis = 1)
roc_df = roc_df1.rename(columns={0:'le_69roc'})
roc_df
# Out:
# 19028

# %%
le_dfs = le_df.dropna()
len(le_dfs)
# Out:
# 18445

# %%
le_dfs.head()
# Out:
#         Entity Code  Year  Life expectancy (years)
# 0  Afghanistan  AFG  1950                   27.638
# 1  Afghanistan  AFG  1951                   27.878
# 2  Afghanistan  AFG  1952                   28.361
# 3  Afghanistan  AFG  1953                   28.852
# 4  Afghanistan  AFG  1954                   29.350

# %%
lef = le_dfs.pivot(index='Code', columns='Year', values='Life expectancy (years)')
#glob_toil['Code'].count_values()
lef.head()
# Out:
# Year  1543  1548  1553  1558  1563  1568  1573  1578  1583  1588  ...    2010  \
# Code                                                              ...
# ABW    NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...  75.017
# AFG    NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...  61.028
# AGO    NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...  55.350
# AIA    NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...  80.903
# ALB    NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...  76.562
#
# Year    2011    2012    2013    2014    2015    2016    2017    2018    2019
# Code
# ABW   75.158  75.299  75.441  75.583  75.725  75.868  76.010  76.152  76.293
# AFG   61.553  62.054  62.525  62.966  63.377  63.763  64.130  64.486  64.833
# AGO   56.330  57.236  58.054  58.776  59.398  59.925  60.379  60.782  61.147
# AIA   81.007  81.090  81.165  81.243  81.332  81.441  81.568  81.714  81.877
# ...

# %%
df.to_csv("percent_child_labor_44_countries.csv", index=True)

# %%
no_null_conflict.to_csv("death_by_conflict_196_countries.csv", index=True)

# %%
PEDS_death.to_csv("ped_deaths_196_countries.csv", index=True)

# %%
sanit.to_csv("prev_sanitation_death_196_countries.csv", index=True)

# %%
homo_death.to_csv("homocide_rate_per100k.csv", index=True)

# %%
nat_dis.to_csv("percent_death_nat_dis.csv", index=True)

# %%
glob_nour.to_csv("percent_pop_maln_166_countries.csv", index=True)

# %%
glob_toil.to_csv("percent_toilets_202_countries.csv", index=True)

# %%
glob_pedX.to_csv("percent_childmort_193_countries.csv", index=True)

# %%
lef.to_csv("lifexp_age_196_countries.csv", index=True)

# %%
#scores_df7
scores_df7.to_csv("scores_4ML2.csv", index=True)

# %%
scores_df_cinc21.to_csv("ML_try3.csv", index=True)

# %%
scores_df_cinc20.head()
# Out:
#    pedmort_2016  pedmort_53mean  pedmort_3mean Code  sanit_2015  sanit_21mean  \
# 0          6.79       20.641667       7.316667  AFG        31.9     24.266667
# 1          0.88        3.666389       0.940000  ALB        93.2     84.009091
# 2          1.04        3.361333       1.143333  ARG        96.4     91.477273
# 3          1.26        4.465526       1.400000  ARM        89.5     89.435000
# 4          0.35        1.239444       0.383333  AUS       100.0    100.000000
#
#    sanit_3mean  maln_12mean  maln_3mean  maln_2016  ...  homoc_2017  \
# 0    31.133333    32.115385   27.466667       30.3  ...   10.673076
# 1    92.666667     8.761538    5.566667        5.5  ...    2.488883
# 2    95.800000     4.315385    3.500000        3.8  ...    6.175149
# 3    89.500000    10.792308    4.400000        4.3  ...    3.691191
# 4   100.000000     2.500000    2.500000        2.5  ...    1.367412
#
#    homoc_3mean  homoc_23mean  Country or region  Outcome  sanit_25roc  \
# ...
